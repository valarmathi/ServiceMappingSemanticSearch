# %%
# !pip install -U -q pdfplumber tiktoken openai chromaDB sentence-transformers

# %%
import pdfplumber
from pathlib import Path
import pandas as pd
from operator import itemgetter
import json
import tiktoken
import openai
import chromadb

# %% [markdown]
# #Stage1: Extract text from PDF

# %%
def check_bboxes(word, table_bbox):
    # Check whether word is inside a table bbox.
    l = word['x0'], word['top'], word['x1'], word['bottom']
    r = table_bbox
    return l[0] > r[0] and l[1] > r[1] and l[2] < r[2] and l[3] < r[3]

# %%
# Function to extract text from a PDF file.
# 1. Declare a variable p to store the iteration of the loop that will help us store page numbers alongside the text
# 2. Declare an empty list 'full_text' to store all the text files
# 3. Use pdfplumber to open the pdf pages one by one
# 4. Find the tables and their locations in the page
# 5. Extract the text from the tables in the variable 'tables'
# 6. Extract the regular words by calling the function check_bboxes() and checking whether words are present in the table or not
# 7. Use the cluster_objects utility to cluster non-table and table words together so that they retain the same chronology as in the original PDF
# 8. Declare an empty list 'lines' to store the page text
# 9. If a text element in present in the cluster, append it to 'lines', else if a table element is present, append the table
# 10. Append the page number and all lines to full_text, and increment 'p'
# 11. When the function has iterated over all pages, return the 'full_text' list

def extract_text_from_pdf(pdf_path):
    p = 0
    full_text = []


    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            page_no = f"Page {p+1}"
            text = page.extract_text()

            tables = page.find_tables()
            table_bboxes = [i.bbox for i in tables]
            tables = [{'table': i.extract(), 'top': i.bbox[1]} for i in tables]
            non_table_words = [word for word in page.extract_words() if not any(
                [check_bboxes(word, table_bbox) for table_bbox in table_bboxes])]
            lines = []

            for cluster in pdfplumber.utils.cluster_objects(non_table_words + tables, itemgetter('top'), tolerance=5):

                if 'text' in cluster[0]:
                    try:
                        lines.append(' '.join([i['text'] for i in cluster]))
                    except KeyError:
                        pass

                elif 'table' in cluster[0]:
                    lines.append(json.dumps(cluster[0]['table']))


            full_text.append([page_no, " ".join(lines)])
            p +=1

    return full_text

# %%
# Define the directory containing the PDF files
pdf_directory = Path("")

# Initialize an empty list to store the extracted texts and document names
data = []

# Loop through all files in the directory
for pdf_path in pdf_directory.glob("*.pdf"):
    print(pdf_path)
    # Process the PDF file
    print(f"...Processing {pdf_path.name}")

    # Call the function to extract the text from the PDF
    extracted_text = extract_text_from_pdf(pdf_path)

    # Convert the extracted list to a PDF, and add a column to store document names
    extracted_text_df = pd.DataFrame(extracted_text, columns=['Page No.', 'Page_Text'])
    extracted_text_df['Document Name'] = pdf_path.name

    # Append the extracted text and document name to the list
    data.append(extracted_text_df)

    # Print a message to indicate progress
    print(f"Finished processing {pdf_path.name}")

# Print a message to indicate all PDFs have been processed
print("All PDFs have been processed.")
# Out:
# Automated Service Suggestions.pdf
# ...Processing Automated Service Suggestions.pdf
# Finished processing Automated Service Suggestions.pdf
# Tag-based discovery in Service Mapping.pdf
# ...Processing Tag-based discovery in Service Mapping.pdf
# Finished processing Tag-based discovery in Service Mapping.pdf
# Pattern-based discovery in Service Mapping.pdf
# ...Processing Pattern-based discovery in Service Mapping.pdf
# Finished processing Pattern-based discovery in Service Mapping.pdf
# Choose the right method for discovery and mapping application services.pdf
# ...Processing Choose the right method for discovery and mapping application services.pdf
# Finished processing Choose the right method for discovery and mapping application services.pdf
# Discovery based on Predictive Intelligence.pdf
# ...Processing Discovery based on Predictive Intelligence.pdf
# Finished processing Discovery based on Predictive Intelligence.pdf
# Traffic-based discovery in Service Mapping.pdf
# ...Processing Traffic-based discovery in Service Mapping.pdf
# Finished processing Traffic-based discovery in Service Mapping.pdf
# All PDFs have been processed.

# %%
data
# Out:
# [  Page No.                                          Page_Text  \
#  0   Page 1  20/06/2024, 16:29 Automated Service Suggestion...
#  1   Page 2  20/06/2024, 16:29 Automated Service Suggestion...
#
#                         Document Name
#  0  Automated Service Suggestions.pdf
#  1  Automated Service Suggestions.pdf  ,
#    Page No.                                          Page_Text  \
#  0   Page 1  20/06/2024, 16:27 Tag-based discovery in Servi...
#  1   Page 2  20/06/2024, 16:27 Tag-based discovery in Servi...
#
#                                  Document Name
#  0  Tag-based discovery in Service Mapping.pdf
#  1  Tag-based discovery in Service Mapping.pdf  ,
#    Page No.                                          Page_Text  \
#  0   Page 1  20/06/2024, 16:28 Pattern-based discovery in S...
#  1   Page 2  20/06/2024, 16:28 Pattern-based discovery in S...
#
#                                      Document Name
#  0  Pattern-based discovery in Service Mapping.pdf
#  1  Pattern-based discovery in Service Mapping.pdf  ,
#    Page No.                                          Page_Text  \
#  0   Page 1  20/06/2024, 16:29 Choose the right method for ...
#  1   Page 2  20/06/2024, 16:29 Choose the right method for ...
#
#                                         Document Name
#  0  Choose the right method for discovery and mapp...
#  1  Choose the right method for discovery and mapp...  ,
#    Page No.                                          Page_Text  \
#  0   Page 1  20/06/2024, 16:29 Discovery based on Predictiv...
#  1   Page 2  20/06/2024, 16:29 Discovery based on Predictiv...
#
#                                      Document Name
#  0  Discovery based on Predictive Intelligence.pdf
#  1  Discovery based on Predictive Intelligence.pdf  ,
#    Page No.                                          Page_Text  \
#  0   Page 1  20/06/2024, 16:28 Traffic-based discovery in S...
#  1   Page 2  20/06/2024, 16:28 Traffic-based discovery in S...
#
#                                      Document Name
#  0  Traffic-based discovery in Service Mapping.pdf
#  1  Traffic-based discovery in Service Mapping.pdf  ]

# %%
# Concatenate all the DFs in the list 'data' together

service_mapping_pdfs_data = pd.concat(data, ignore_index=True)

# %%
service_mapping_pdfs_data
# Out:
#    Page No.                                          Page_Text  \
# 0    Page 1  20/06/2024, 16:29 Automated Service Suggestion...
# 1    Page 2  20/06/2024, 16:29 Automated Service Suggestion...
# 2    Page 1  20/06/2024, 16:27 Tag-based discovery in Servi...
# 3    Page 2  20/06/2024, 16:27 Tag-based discovery in Servi...
# 4    Page 1  20/06/2024, 16:28 Pattern-based discovery in S...
# 5    Page 2  20/06/2024, 16:28 Pattern-based discovery in S...
# 6    Page 1  20/06/2024, 16:29 Choose the right method for ...
# 7    Page 2  20/06/2024, 16:29 Choose the right method for ...
# 8    Page 1  20/06/2024, 16:29 Discovery based on Predictiv...
# 9    Page 2  20/06/2024, 16:29 Discovery based on Predictiv...
# 10   Page 1  20/06/2024, 16:28 Traffic-based discovery in S...
# 11   Page 2  20/06/2024, 16:28 Traffic-based discovery in S...
#
#                                         Document Name
# 0                   Automated Service Suggestions.pdf
# 1                   Automated Service Suggestions.pdf
# 2          Tag-based discovery in Service Mapping.pdf
# 3          Tag-based discovery in Service Mapping.pdf
# 4      Pattern-based discovery in Service Mapping.pdf
# 5      Pattern-based discovery in Service Mapping.pdf
# 6   Choose the right method for discovery and mapp...
# 7   Choose the right method for discovery and mapp...
# 8      Discovery based on Predictive Intelligence.pdf
# 9      Discovery based on Predictive Intelligence.pdf
# 10     Traffic-based discovery in Service Mapping.pdf
# 11     Traffic-based discovery in Service Mapping.pdf

# %%
service_mapping_pdfs_data['Text Length'] = service_mapping_pdfs_data['Page_Text'].apply(lambda x: len(x.split(' ')))

# %%
service_mapping_pdfs_data
# Out:
#    Page No.                                          Page_Text  \
# 0    Page 1  20/06/2024, 16:29 Automated Service Suggestion...
# 1    Page 2  20/06/2024, 16:29 Automated Service Suggestion...
# 2    Page 1  20/06/2024, 16:27 Tag-based discovery in Servi...
# 3    Page 2  20/06/2024, 16:27 Tag-based discovery in Servi...
# 4    Page 1  20/06/2024, 16:28 Pattern-based discovery in S...
# 5    Page 2  20/06/2024, 16:28 Pattern-based discovery in S...
# 6    Page 1  20/06/2024, 16:29 Choose the right method for ...
# 7    Page 2  20/06/2024, 16:29 Choose the right method for ...
# 8    Page 1  20/06/2024, 16:29 Discovery based on Predictiv...
# 9    Page 2  20/06/2024, 16:29 Discovery based on Predictiv...
# 10   Page 1  20/06/2024, 16:28 Traffic-based discovery in S...
# 11   Page 2  20/06/2024, 16:28 Traffic-based discovery in S...
#
#                                         Document Name  Text Length
# 0                   Automated Service Suggestions.pdf          220
# 1                   Automated Service Suggestions.pdf           25
# 2          Tag-based discovery in Service Mapping.pdf          628
# 3          Tag-based discovery in Service Mapping.pdf           27
# 4      Pattern-based discovery in Service Mapping.pdf          438
# 5      Pattern-based discovery in Service Mapping.pdf          394
# 6   Choose the right method for discovery and mapp...          881
# 7   Choose the right method for discovery and mapp...           32
# 8      Discovery based on Predictive Intelligence.pdf          754
# 9      Discovery based on Predictive Intelligence.pdf           27
# 10     Traffic-based discovery in Service Mapping.pdf          840
# 11     Traffic-based discovery in Service Mapping.pdf           35

# %%
service_mapping_pdfs_data = service_mapping_pdfs_data[service_mapping_pdfs_data['Text Length'] > 20]

# %%
service_mapping_pdfs_data
# Out:
#    Page No.                                          Page_Text  \
# 0    Page 1  20/06/2024, 16:29 Automated Service Suggestion...
# 1    Page 2  20/06/2024, 16:29 Automated Service Suggestion...
# 2    Page 1  20/06/2024, 16:27 Tag-based discovery in Servi...
# 3    Page 2  20/06/2024, 16:27 Tag-based discovery in Servi...
# 4    Page 1  20/06/2024, 16:28 Pattern-based discovery in S...
# 5    Page 2  20/06/2024, 16:28 Pattern-based discovery in S...
# 6    Page 1  20/06/2024, 16:29 Choose the right method for ...
# 7    Page 2  20/06/2024, 16:29 Choose the right method for ...
# 8    Page 1  20/06/2024, 16:29 Discovery based on Predictiv...
# 9    Page 2  20/06/2024, 16:29 Discovery based on Predictiv...
# 10   Page 1  20/06/2024, 16:28 Traffic-based discovery in S...
# 11   Page 2  20/06/2024, 16:28 Traffic-based discovery in S...
#
#                                         Document Name  Text Length
# 0                   Automated Service Suggestions.pdf          220
# 1                   Automated Service Suggestions.pdf           25
# 2          Tag-based discovery in Service Mapping.pdf          628
# 3          Tag-based discovery in Service Mapping.pdf           27
# 4      Pattern-based discovery in Service Mapping.pdf          438
# 5      Pattern-based discovery in Service Mapping.pdf          394
# 6   Choose the right method for discovery and mapp...          881
# 7   Choose the right method for discovery and mapp...           32
# 8      Discovery based on Predictive Intelligence.pdf          754
# 9      Discovery based on Predictive Intelligence.pdf           27
# 10     Traffic-based discovery in Service Mapping.pdf          840
# 11     Traffic-based discovery in Service Mapping.pdf           35

# %%
service_mapping_pdfs_data['Metadata'] = service_mapping_pdfs_data.apply(lambda x: {'Document Name':x['Document Name'],'Page No':x['Page No.']}, axis=1)

# %%
service_mapping_pdfs_data
# Out:
#    Page No.                                          Page_Text  \
# 0    Page 1  20/06/2024, 16:29 Automated Service Suggestion...
# 1    Page 2  20/06/2024, 16:29 Automated Service Suggestion...
# 2    Page 1  20/06/2024, 16:27 Tag-based discovery in Servi...
# 3    Page 2  20/06/2024, 16:27 Tag-based discovery in Servi...
# 4    Page 1  20/06/2024, 16:28 Pattern-based discovery in S...
# 5    Page 2  20/06/2024, 16:28 Pattern-based discovery in S...
# 6    Page 1  20/06/2024, 16:29 Choose the right method for ...
# 7    Page 2  20/06/2024, 16:29 Choose the right method for ...
# 8    Page 1  20/06/2024, 16:29 Discovery based on Predictiv...
# 9    Page 2  20/06/2024, 16:29 Discovery based on Predictiv...
# 10   Page 1  20/06/2024, 16:28 Traffic-based discovery in S...
# 11   Page 2  20/06/2024, 16:28 Traffic-based discovery in S...
#
#                                         Document Name  Text Length  \
# 0                   Automated Service Suggestions.pdf          220
# 1                   Automated Service Suggestions.pdf           25
# 2          Tag-based discovery in Service Mapping.pdf          628
# 3          Tag-based discovery in Service Mapping.pdf           27
# 4      Pattern-based discovery in Service Mapping.pdf          438
# 5      Pattern-based discovery in Service Mapping.pdf          394
# 6   Choose the right method for discovery and mapp...          881
# 7   Choose the right method for discovery and mapp...           32
# 8      Discovery based on Predictive Intelligence.pdf          754
# 9      Discovery based on Predictive Intelligence.pdf           27
# 10     Traffic-based discovery in Service Mapping.pdf          840
# 11     Traffic-based discovery in Service Mapping.pdf           35
#
#                                              metadata  \
# 0   {'Document Name': 'Automated Service Suggestio...
# 1   {'Document Name': 'Automated Service Suggestio...
# 2   {'Document Name': 'Tag-based discovery in Serv...
# 3   {'Document Name': 'Tag-based discovery in Serv...
# 4   {'Document Name': 'Pattern-based discovery in ...
# 5   {'Document Name': 'Pattern-based discovery in ...
# 6   {'Document Name': 'Choose the right method for...
# 7   {'Document Name': 'Choose the right method for...
# 8   {'Document Name': 'Discovery based on Predicti...
# 9   {'Document Name': 'Discovery based on Predicti...
# 10  {'Document Name': 'Traffic-based discovery in ...
# 11  {'Document Name': 'Traffic-based discovery in ...
#
#                                              Metadata
# 0   {'Document Name': 'Automated Service Suggestio...
# 1   {'Document Name': 'Automated Service Suggestio...
# 2   {'Document Name': 'Tag-based discovery in Serv...
# 3   {'Document Name': 'Tag-based discovery in Serv...
# 4   {'Document Name': 'Pattern-based discovery in ...
# 5   {'Document Name': 'Pattern-based discovery in ...
# 6   {'Document Name': 'Choose the right method for...
# 7   {'Document Name': 'Choose the right method for...
# 8   {'Document Name': 'Discovery based on Predicti...
# 9   {'Document Name': 'Discovery based on Predicti...
# 10  {'Document Name': 'Traffic-based discovery in ...
# 11  {'Document Name': 'Traffic-based discovery in ...

# %%
service_mapping_pdfs_data.drop('metadata', axis=1)
# Out:
#    Page No.                                          Page_Text  \
# 0    Page 1  20/06/2024, 16:29 Automated Service Suggestion...
# 1    Page 2  20/06/2024, 16:29 Automated Service Suggestion...
# 2    Page 1  20/06/2024, 16:27 Tag-based discovery in Servi...
# 3    Page 2  20/06/2024, 16:27 Tag-based discovery in Servi...
# 4    Page 1  20/06/2024, 16:28 Pattern-based discovery in S...
# 5    Page 2  20/06/2024, 16:28 Pattern-based discovery in S...
# 6    Page 1  20/06/2024, 16:29 Choose the right method for ...
# 7    Page 2  20/06/2024, 16:29 Choose the right method for ...
# 8    Page 1  20/06/2024, 16:29 Discovery based on Predictiv...
# 9    Page 2  20/06/2024, 16:29 Discovery based on Predictiv...
# 10   Page 1  20/06/2024, 16:28 Traffic-based discovery in S...
# 11   Page 2  20/06/2024, 16:28 Traffic-based discovery in S...
#
#                                         Document Name  Text Length  \
# 0                   Automated Service Suggestions.pdf          220
# 1                   Automated Service Suggestions.pdf           25
# 2          Tag-based discovery in Service Mapping.pdf          628
# 3          Tag-based discovery in Service Mapping.pdf           27
# 4      Pattern-based discovery in Service Mapping.pdf          438
# 5      Pattern-based discovery in Service Mapping.pdf          394
# 6   Choose the right method for discovery and mapp...          881
# 7   Choose the right method for discovery and mapp...           32
# 8      Discovery based on Predictive Intelligence.pdf          754
# 9      Discovery based on Predictive Intelligence.pdf           27
# 10     Traffic-based discovery in Service Mapping.pdf          840
# 11     Traffic-based discovery in Service Mapping.pdf           35
#
#                                              Metadata
# 0   {'Document Name': 'Automated Service Suggestio...
# 1   {'Document Name': 'Automated Service Suggestio...
# 2   {'Document Name': 'Tag-based discovery in Serv...
# 3   {'Document Name': 'Tag-based discovery in Serv...
# 4   {'Document Name': 'Pattern-based discovery in ...
# 5   {'Document Name': 'Pattern-based discovery in ...
# 6   {'Document Name': 'Choose the right method for...
# 7   {'Document Name': 'Choose the right method for...
# 8   {'Document Name': 'Discovery based on Predicti...
# 9   {'Document Name': 'Discovery based on Predicti...
# 10  {'Document Name': 'Traffic-based discovery in ...
# 11  {'Document Name': 'Traffic-based discovery in ...

# %%
#Initialize chroma collection

# %%
from chromadb.utils.embedding_functions import OpenAIEmbeddingFunction

# %%
chroma_data_path = 'chroma'

# %%
import chromadb

# %%
# Call PersistentClient()

client = chromadb.PersistentClient()

# %%
openai.api_key = 'sk-proj-BRC4WIZodN7n84tyYxgLT3BlbkFJTxzb5ZgPgBzHJumS0HpC'

# %%
# Set up the embedding function using the OpenAI embedding model

model = "text-embedding-ada-002"
embedding_function = OpenAIEmbeddingFunction(api_key=openai.api_key, model_name=model)

# %%
document_collection = client.get_or_create_collection(name='RAG_on_ServiceNow_Documents', embedding_function=embedding_function)

# %%
# Convert the page text and metadata from your dataframe to lists to be able to pass it to chroma

documents_list = service_mapping_pdfs_data["Page_Text"].tolist()
metadata_list = service_mapping_pdfs_data['Metadata'].tolist()

# %%
document_collection.add(
    documents= documents_list,
    ids = [str(i) for i in range(0, len(documents_list))],
    metadatas = metadata_list
)

# %%
# Let's take a look at the first few entries in the collection

document_collection.get(
    ids = ['0'],
    include = ['embeddings', 'documents', 'metadatas']
)
# Out:
# {'ids': ['0'],
#  'embeddings': [[-0.021748917177319527,
#    -0.006173198577016592,
#    0.0024056558031588793,
#    -0.009402520954608917,
#    -0.028916018083691597,
#    0.011108318343758583,
#    -0.012504595331847668,
#    0.008749090135097504,
#    -0.03298792243003845,
#    -0.016026241704821587,
#    0.005863678641617298,
#    0.0033840821124613285,
#    -0.014334200881421566,
#    -0.01145910657942295,
#    -0.007297786418348551,
#    0.024183806031942368,
#    0.02437639608979225,
#    -0.01214692834764719,
#    -0.0006091519608162344,
#    -0.019217733293771744,
#    -0.006066585890948772,
#    -0.004990145564079285,
#    0.004154442343860865,
#    -0.022533033043146133,
#    -0.011204613372683525,
#    0.018488643690943718,
#    0.0014693588018417358,
#    -0.04762476310133934,
#    -0.0030951970256865025,
#    0.021803943440318108,
#    0.013660135678946972,
#    -0.02996150590479374,
#    -0.019396567717194557,
#    -0.006448327098041773,
#    0.0047631640918552876,
#    0.005574793554842472,
#    0.019878042861819267,
#    -0.008370787836611271,
#    0.01361886691302061,
#    -0.02623351477086544,
#    -0.004357349593192339,
#    0.010448009707033634,
#    0.010853824205696583,
#    -0.03758256882429123,
#    -0.019767992198467255,
#    0.019754234701395035,
#    -0.015916191041469574,
#    -0.030869431793689728,
#    0.002096136100590229,
#    0.017855847254395485,
#    0.010695625096559525,
#    0.025174269452691078,
#    -0.02191399410367012,
#    0.002369545167312026,
#    -0.005849922075867653,
#    0.011424715630710125,
#    -0.030374199151992798,
#    0.009560719132423401,
#    0.019644184038043022,
#    -0.006809433456510305,
#    0.0007230723858810961,
#    -0.005079562310129404,
#    -0.028805967420339584,
#    -0.002835544291883707,
#    -0.0032981042750179768,
#    -0.02809063158929348,
#    -0.022092828527092934,
#    0.02385365217924118,
#    0.0016232588095590472,
#    -0.004659990780055523,
#    0.019630426540970802,
#    0.04490099102258682,
#    0.018694989383220673,
#    -0.024610254913568497,
#    0.020139414817094803,
#    -0.010055950842797756,
#    -0.022684354335069656,
#    -0.004553378559648991,
#    -0.010922606103122234,
#    -0.0017092365305870771,
#    -0.0033565692137926817,
#    -0.012704064138233662,
#    -0.006204150151461363,
#    0.03560164198279381,
#    0.017388129606842995,
#    0.026935091242194176,
#    0.00415100296959281,
#    0.011259638704359531,
#    -0.016947923228144646,
#    -0.00022655121574644,
#    0.0189838744699955,
#    -0.0008645057096146047,
#    -0.0030350126326084137,
#    0.03128212317824364,
#    0.19016890227794647,
#    0.011844286695122719,
#    0.011376568116247654,
#    0.02952130138874054,
#    -0.004285128321498632,
#    0.0162050761282444,
#    0.02615097537636757,
#    0.019795503467321396,
#    -0.00439517991617322,
#    0.001618959940969944,
#    -0.017484424635767937,
#    -0.0032602741848677397,
#    -0.0022096268367022276,
#    0.00125355483032763,
#    0.010331079363822937,
#    -0.01909392699599266,
#    -0.03496884927153587,
#    -0.04322270676493645,
#    0.004684064537286758,
#    0.00010591377213131636,
#    0.01665903814136982,
#    -0.011844286695122719,
#    -0.012876019813120365,
#    -0.02194150723516941,
#    0.01854366809129715,
#    0.010785042308270931,
#    -0.004536183085292578,
#    -0.00678535969927907,
#    -0.0008726735832169652,
#    0.03752754256129265,
#    -0.03130963817238808,
#    0.029356224462389946,
#    0.018323566764593124,
#    0.028338247910141945,
#    -0.024156292900443077,
#    0.005182735156267881,
#    0.006362349260598421,
#    0.011796139180660248,
#    0.01570984348654747,
#    0.01811721920967102,
#    -0.00762106291949749,
#    -0.011569158174097538,
#    0.0018502399325370789,
#    -0.014884457923471928,
#    -0.022725623100996017,
#    0.012243223376572132,
#    ...]],
#  'metadatas': [{'Document Name': 'Automated Service Suggestions.pdf',
#    'Page No': 'Page 1'}],
#  'documents': ['20/06/2024, 16:29 Automated Service Suggestions [["Table of Contents"], ["Automated Service Suggestions\\nRelease version: Washington DC\\nUpdated Feb 1, 2024\\n1 minute read\\nAutomated Service Suggestions uses machine-learning data to help you map a new application service or to add to an existing service in minutes.\\nService Mapping offers the visibility needed for effective service operations. Mapped services with business criticality identi\\u0000ed provide key information to make data-driven decisions, prioritize services, and respond to\\nsituations as needed.\\nUsing Machine Learning, Service Mapping identi\\u0000es potential application \\u0000ngerprints based on discovered processes. It evaluates the relationship between these \\u0000ngerprints and CIs and creates meaningful connections.\\nThese connections are used to create an application service map, a visual representation of a service. Machine Learning has reduced this process from weeks to minutes.\\nAutomated Service Suggestions takes the information provided by Machine Learning and further simpli\\u0000es the mapping process. It calculates entry points, eliminating the challenge related to knowing where to begin\\nmapping an application service. It also generates a list of application service candidates. Each candidate includes an entry point as well as a set of previously identi\\u0000ed resources to include in the service map. Then in a few\\nclicks, the user can then select a candidate to create a new application service or to add to an existing service.\\nPrevious\\nChoose the right method for discovery and mapping application services\\nNext\\nDiscovery based on Predictive Intelligence"]] https://docs.servicenow.com/bundle/washingtondc-it-operations-management/page/product/service-mapping/concept/auto-serv-suggest.html 1/2'],
#  'uris': None,
#  'data': None,
#  'included': ['embeddings', 'documents', 'metadatas']}

# %%
query = input()
# Out:
#   What is a tag based service?

# %%
results = document_collection.query(
query_texts=query,
n_results=5
)

# %%
results
# Out:
# {'ids': [['2', '3', '11', '6', '10']],
#  'distances': [[0.3082152685998024,
#    0.3658776687214737,
#    0.3957040648481214,
#    0.43148983202573366,
#    0.4408169355308555]],
#  'metadatas': [[{'Document Name': 'Tag-based discovery in Service Mapping.pdf',
#     'Page No': 'Page 1'},
#    {'Document Name': 'Tag-based discovery in Service Mapping.pdf',
#     'Page No': 'Page 2'},
#    {'Document Name': 'Traffic-based discovery in Service Mapping.pdf',
#     'Page No': 'Page 2'},
#    {'Document Name': 'Choose the right method for discovery and mapping application services.pdf',
#     'Page No': 'Page 1'},
#    {'Document Name': 'Traffic-based discovery in Service Mapping.pdf',
#     'Page No': 'Page 1'}]],
#  'embeddings': None,
#  'documents': [['20/06/2024, 16:27 Tag-based discovery in Service Mapping [["Table of Contents"], ["Tag-based discovery in Service Mapping\\nRelease version: Washington DC\\nUpdated Feb 1, 2024\\n3 minutes to read\\nSummarize [Beta]\\nGPT summary: This tool offers a brief overview. For more detailed information, refer to the full topic.\\nIf your organization uses tags for asset management, you can use these tags to map application services.\\nA tag is a label that consists of a key-value pair. Your organization may use tags to categorize its assets, to enhance query and reporting capabilities. Discovery and Cloud Provisioning and Governance can discover tags used\\nby all major cloud providers and container ecosystems. Once the tags are discovered, Service Mapping can create application services based on these tags. Typically organizations use tagging in virtualized, hyper-converged,\\nor multi-cloud infrastructures.\\nExample of using tagging in organization infrastructure\\nSegment Technology providers What is tagged\\nAmazon Web Services (AWS), Azure, Google Cloud Platform (GCP),\\nCloud IaaS, PaaS, FaaS, CaaS resources\\nIBM Cloud Platform\\nHyper-converged Nutanix Virtual machines\\nContainers Kubernetes, OpenShift Container Platform, AWS ECS Containers\\nVirtualization VMware vCenter Virtual machines\\nUnlike other mapping methods, tag-based mapping does not require con\\u0000guring credentials or providing users with elevated rights. You can effectively use tags to map multiple application services.\\nThe tag-based discovery and mapping process consists of the following stages:\\n1. Discovery and Cloud Provisioning and Governance discover tags for cloud and resource CIs and then populate data for discovered tags into the Key Value [cmdb_key_value] table.\\n2. The administrator creates CI tag categories and de\\u0000nes tag keys that the categories contain. Tag categories contain tags with similar use, for example, tags related to different types of environments, if the organization\\nuses \\"production\\" and \\"staging\\" tag values.\\n3. The administrator creates a tag-based service family and selects tag categories to use for its mapping. Only CIs that have discovered tag values for the selected tag categories become part of application services. The\\nadministrator can narrow the criteria down by de\\u0000ning the tag values in addition to tag categories. In this case, Service Mapping uses only CIs that have the matching values to create application services. CIs that have\\nmore than one tags assigned to them, can be part of multiple services.\\nNote: When creating a service family for mapping services based on tags in domain-separated environment, you must pick the relevant leaf domain. Service Mapping populates tag-based services based on this\\nservice family only with CIs belonging to the leaf domain to which the service family belongs.\\n4. Service Mapping queries the CMDB for CIs with tag values that match the tag de\\u0000nitions for this tag-based service family.\\n5. Service Mapping creates service candidates based on the de\\u0000ned tags.\\nService Mapping populates tag-based services based on this service family only with CIs belonging to the leaf domain to which the service family belongs.\\n6. The administrator selects the service candidates to map and starts the mapping process.\\n7. Service Mapping adds new application services to the Tag-Based Application Service [cmdb_ci_service_by_tags] table.\\nImportant: Tag-based application services may not include relevant CIs, if these CIs do not have the correct tags assigned to them.\\n8. Service Mapping maps application services by creating connections between tagged CIs based on CI relationships. The Traversal Rules for Application Services [svc_traversal_rules] table contains information used for\\ncreating tag-based application services.\\nNote: Service Mapping includes CIs that are part of these relationships even if these CIs do not have tags assig ...
#    '20/06/2024, 16:27 Tag-based discovery in Service Mapping The world works with ServiceNow.™ Terms and conditions Privacy statement GDPR Cookie policy ©2024 ServiceNow. All rights reserved. https://docs.servicenow.com/bundle/washingtondc-it-operations-management/page/product/service-mapping/concept/tag-based-mapping.html 2/2',
#    '20/06/2024, 16:28 Traffic-based discovery in Service Mapping [["Previous\\nTag-based discovery in Service Mapping\\nNext\\nDiscovery of application services on cloud using Service Mapping"], ["The world works with ServiceNow.\\u2122\\nTerms and conditions\\nPrivacy statement\\nGDPR\\nCookie policy\\n\\u00a92024 ServiceNow. All rights reserved."]] https://docs.servicenow.com/bundle/washingtondc-it-operations-management/page/product/service-mapping/concept/traffic-based-discovery.html 2/2',
#    '20/06/2024, 16:29 Choose the right method for discovery and mapping application services [["Table of Contents"], ["Choose the right method for discovery and mapping application services\\nRelease version: Washington DC\\nUpdated Feb 1, 2024\\n2 minutes to read\\nSummarize [Beta]\\nService Mapping deploys different methods for collecting information about con\\u0000guration items (CIs) and organizing them into application services. The available mapping methods are: pattern-based, tag-based, traf\\u0000c-\\nbased, and discovery based on Predictive Intelligence. Learn about the mapping methods to use the ones that best suit the needs of your organization.\\nMapping method Description Advantages Disadvantages\\nWhen using discovery based on Predictive\\nPredictive Intelligence evaluates connections\\nIntelligence to identify TCP connections and\\nbetween application \\u0000ngerprints, CIs, and Service Mapping automatically adds CI connections\\nprocesses, deploy it in large on-premise\\nprocesses, and ranks their relevancy. Service and CIs they lead to based on connection rules. You\\ndeployments. Predictive Intelligence is a machine\\nMapping uses this information to create can modify the default connection rules or create\\nAutomated Service Suggestions learning solution and needs training. To achieve\\nconnections based on connection rules. It also your own to enhance this discovery method.\\nbest results using this discovery method, you must\\ngenerates connection suggestions for servers and Discovery based on Predictive Intelligence is\\nrun discovery repeatedly.\\nload balancers for you to decide which connections effective for mapping multiple application services.\\nService Mapping may erroneously add or remove\\nto add or remove from the application services.\\ndynamic connections.\\nService Mapping uses patterns to discover and map\\nPattern-based mapping requires con\\u0000guring\\nCIs. A pattern is a sequence of commands whose Pattern-based discovery creates precise and\\ncredentials, users, and user permissions to let\\npurpose it is to detect attributes of a CI and its complete application services that reliably\\nPattern-based discovery Service Mapping access applications inside your\\noutbound connections. A typical Service Mapping represent the service-aware view of your\\norganization private network. This process may\\npattern consists of separate algorithms for organization\'s IT infrastructure.\\ntake time and effort.\\nidentifying CIs and \\u0000nding CI connections.\\nIf your organization uses tags for asset\\nmanagement, you can use these tags to map\\napplication services. Discovery and Cloud Tag-based application services may not include\\nYou can effectively use tags to map multiple\\nTag-based discovery Provisioning and Governance discover tags relevant CIs, if these CIs do not have the correct\\napplication services.\\nassigned to CIs, and populate the CMDB with this tags assigned to them.\\ndata. Service Mapping uses the tag-related data\\nfrom the CMDB to map services.\\nWhile using traf\\u0000c-based discovery creates a more\\nService Mapping can discover and map inclusive map, it may also result in mapping many\\ncon\\u0000guration items (CIs) following their traf\\u0000c- redundant CIs that do not in\\u0000uence the application\\nbased connections. This method is referred to as Using traf\\u0000c-based discovery is like casting a \\u0000ner service operation. It may clutter an application\\nTraf\\u0000c-based discovery traf\\u0000c-based mapping and it complements the net, allowing Service Mapping to \\u0000nd even those service with irrelevant CIs. Use traf\\u0000c-based\\npattern-based mapping. CIs that it failed to discover using patterns. discovery at the initial stages of discovering an\\nDepending on your con\\u0000guration, the behavior of application service and disable it once you\\ntraf\\u0000c-based discovery varies. completed discovery and \\u0000ne-tuned the application\\nservice ...
#    '20/06/2024, 16:28 Traffic-based discovery in Service Mapping [["Table of Contents"], ["Tra\\u0000c-based discovery in Service Mapping\\nRelease version: Washington DC\\nUpdated Feb 1, 2024\\n4 minutes to read\\nSummarize [Beta]\\nService Mapping can discover and map con\\u0000guration items (CIs) following their traf\\u0000c-based connections. This method is referred to as traf\\u0000c-based mapping and it complements the pattern-based mapping.\\nWhat is traf\\u0000c-based mapping\\nUsing traf\\u0000c-based discovery is like casting a \\u0000ner net, allowing Service Mapping to \\u0000nd even those CIs that it hasn\'t discovered using patterns. If a CI has two connections, the traf\\u0000c-based connection disappears after the\\nnext top-down discovery, and any manual or pattern-based connections remain.\\nDepending on your con\\u0000guration, the behavior of traf\\u0000c-based discovery varies. If discovery based on Predictive Intelligence is enabled, Service Mapping automatically adds connections to application services based on\\nconnection rules. Service Mapping generates these suggestions based on traf\\u0000c-related data from the Con\\u0000guration Management Database (CMDB) and on Predictive Intelligence analysis of application \\u0000ngerprints, CIs,\\nand processes.\\nIf discovery based Predictive Intelligence is disabled, Service Mapping automatically adds traf\\u0000c-based connections based on the CMDB data to application services. You may need to remove connections leading to\\nirrelevant CIs to declutter application services. Typically, if the connection suggestions feature is turned off, you use traf\\u0000c-based discovery at the initial stages of discovering application services. Disable traf\\u0000c-based\\ndiscovery after you complete discovery and \\u0000ne-tuning of application services.\\nIf pattern-based discovery runs after traf\\u0000c-based discovery runs, it may create duplicate connections between CIs. In that case, the system removes the connection created using traf\\u0000c-based discovery. The system keeps\\nany connection created by traf\\u0000c-based discovery and not discovered using patterns.\\nTraf\\u0000c-related data from the CMDB\\nThe system uses commands and network \\u0000ow logs to collect traf\\u0000c-related data and saves it in the CMDB tables. Service Mapping retrieves this data from the tables to detect CI inbound and outbound connections.\\nTables containing data collected using traf\\u0000c-based methods\\nTable Source Used by Service Mapping to\\nFlow Connector [sa_\\u0000ow_connection] Net\\u0000ow and VPC logs Discover dependencies, add connections during top-down discovery.\\nDiscover all services listening on ports. In a base system, Service\\nFlow Services IP/Port and Statistics [sa_\\u0000ow_service] Net\\u0000ow and VPC logs\\nMapping does not use data from this table.\\nDiscover services communicating to other services. In a base system,\\nFlow Server Communication [sa_\\u0000ow_server_comm] Net\\u0000ow and VPC logs\\nService Mapping does not use data from this table.\\nTCP Connection [cmdb_tcp] netstat and lsof commands Discover connections during top-down discovery.\\nIn base systems, traf\\u0000c-based discovery uses only TCP-related data collected with the help of the netstat, ss, and lsof commands. Discovery based on Net\\u0000ow and VPC logs requires additional con\\u0000guration. You can\\nenrich your traf\\u0000c-based discovery by con\\u0000guring Service Mapping to perform data collection using Net\\u0000ow and VPC logs. In addition, Service Mapping has access to the TCP connection data collected by improved\\nApplication Dependency Mapping (ADM). Discovery performs ADM as part of horizontal discovery.\\nEnabling traf\\u0000c-based discovery in the system\\nBy default, traf\\u0000c-based discovery using commands is available in Service Mapping allowing it to use this method at all levels. You can enable traf\\u0000c-based discovery at different levels,  ...
#    0.007499256636947393,
#    0.004165070131421089,
#    0.009636828675866127,
#    -0.015268373303115368,
#    0.004875226877629757,
#    0.0013901321217417717,
#    -0.011824112385511398,
#    -0.026914946734905243,
#    -0.021020643413066864,
#    -0.021489348262548447,
#    -0.0008916907827369869,
#    0.032667215913534164,
#    0.018847564235329628,
#    0.00860000029206276,
#    0.00016400185995735228,
#    -0.011263088323175907,
#    0.028392072767019272,
#    0.014700247906148434,
#    0.0018117878353223205,
#    -0.017626093700528145,
#    0.0037780345883220434,
#    0.025579851120710373,
#    -0.030906029045581818,
#    0.012527167797088623,
#    0.01890437677502632,
#    0.01877654902637005,
#    -0.007889843545854092,
#    0.0015419281553477049,
#    -0.017143188044428825,
#    0.02089281566441059,
#    -0.0019387283828109503,
#    0.009054500609636307,
#    0.036019157618284225,
#    -0.0049142856150865555,
#    0.0033164327032864094,
#    -0.005070520099252462,
#    -0.0035348059609532356,
#    0.004165070131421089,
#    ...]],
#  'metadatas': [{'distances0': '0.3078151503686226',
#    'distances1': '0.3659185052446225',
#    'distances2': '0.3955104940209237',
#    'distances3': '0.4310198282301936',
#    'distances4': '0.4405866981190856',
#    'distances5': '0.44965622028885094',
#    'distances6': '0.4527417983379455',
#    'distances7': '0.47044855818736603',
#    'distances8': '0.47123056877887776',
#    'distances9': '0.4754909042662561',
#    'documents0': '20/06/2024, 16:27 Tag-based discovery in Service Mapping [["Table of Contents"], ["Tag-based discovery in Service Mapping\\nRelease version: Washington DC\\nUpdated Feb 1, 2024\\n3 minutes to read\\nSummarize [Beta]\\nGPT summary: This tool offers a brief overview. For more detailed information, refer to the full topic.\\nIf your organization uses tags for asset management, you can use these tags to map application services.\\nA tag is a label that consists of a key-value pair. Your organization may use tags to categorize its assets, to enhance query and reporting capabilities. Discovery and Cloud Provisioning and Governance can discover tags used\\nby all major cloud providers and container ecosystems. Once the tags are discovered, Service Mapping can create application services based on these tags. Typically organizations use tagging in virtualized, hyper-converged,\\nor multi-cloud infrastructures.\\nExample of using tagging in organization infrastructure\\nSegment Technology providers What is tagged\\nAmazon Web Services (AWS), Azure, Google Cloud Platform (GCP),\\nCloud IaaS, PaaS, FaaS, CaaS resources\\nIBM Cloud Platform\\nHyper-converged Nutanix Virtual machines\\nContainers Kubernetes, OpenShift Container Platform, AWS ECS Containers\\nVirtualization VMware vCenter Virtual machines\\nUnlike other mapping methods, tag-based mapping does not require con\\u0000guring credentials or providing users with elevated rights. You can effectively use tags to map multiple application services.\\nThe tag-based discovery and mapping process consists of the following stages:\\n1. Discovery and Cloud Provisioning and Governance discover tags for cloud and resource CIs and then populate data for discovered tags into the Key Value [cmdb_key_value] table.\\n2. The administrator creates CI tag categories and de\\u0000nes tag keys that the categories contain. Tag categories contain tags with similar use, for example, tags related to different types of environments, if the organization\\nuses \\"production\\" and \\"staging\\" tag values.\\n3. The administrator creates a tag-based service family and selects tag categories to use for its mapping. Only CIs that have discovered tag values for the selected tag categories become part of application services. The\\nadministrator can narrow the criteria down by de\\u0000ning the tag values in addition to tag categories. In this case, Service Mapping uses only CIs that have the matching values to create application services. CIs that have\\nmore than one tags assigned to them, can be part of multiple services.\\nNote: When creating a service family for mapping services based on tags in domain-separated environment, you must pick the relevant leaf domain. Service Mapping populates tag-based services based on this\\nservice family only with CIs belonging to the leaf domain to which the service family belongs.\\n4. Service Mapping queries the CMDB for CIs with tag values that match the tag de\\u0000nitions for this tag-based service family.\\n5. Service Mapping creates service candidates based on the de\\u0000ned tags.\\nService Mapping populates tag-based services based on this service family only with CIs belonging to the leaf domain to which the service family belongs.\\n6. The administrator selects the service candidates to map and starts the mapping process.\\n7. Service Mapping adds new application services to the Tag-Based Application Service [cmdb_ci_service_by_tags] table.\\nImportant: Tag-based application services may not include relevant CIs, if these CIs do not have the correct tags assigned to them.\\n8. Service Mapping maps application services by creating connections between tagged CIs based on CI relationships. The Traversal Rules for Application Services [svc_traversal_rules] table contains information used for\\ncreating tag-based application services.\\nNote: Service Mapping includes CIs that are part of these relationships even if these CIs do not have tags assi ...
#    'documents1': '20/06/2024, 16:27 Tag-based discovery in Service Mapping The world works with ServiceNow.™ Terms and conditions Privacy statement GDPR Cookie policy ©2024 ServiceNow. All rights reserved. https://docs.servicenow.com/bundle/washingtondc-it-operations-management/page/product/service-mapping/concept/tag-based-mapping.html 2/2',
#    'documents2': '20/06/2024, 16:28 Traffic-based discovery in Service Mapping [["Previous\\nTag-based discovery in Service Mapping\\nNext\\nDiscovery of application services on cloud using Service Mapping"], ["The world works with ServiceNow.\\u2122\\nTerms and conditions\\nPrivacy statement\\nGDPR\\nCookie policy\\n\\u00a92024 ServiceNow. All rights reserved."]] https://docs.servicenow.com/bundle/washingtondc-it-operations-management/page/product/service-mapping/concept/traffic-based-discovery.html 2/2',
#    'documents3': '20/06/2024, 16:29 Choose the right method for discovery and mapping application services [["Table of Contents"], ["Choose the right method for discovery and mapping application services\\nRelease version: Washington DC\\nUpdated Feb 1, 2024\\n2 minutes to read\\nSummarize [Beta]\\nService Mapping deploys different methods for collecting information about con\\u0000guration items (CIs) and organizing them into application services. The available mapping methods are: pattern-based, tag-based, traf\\u0000c-\\nbased, and discovery based on Predictive Intelligence. Learn about the mapping methods to use the ones that best suit the needs of your organization.\\nMapping method Description Advantages Disadvantages\\nWhen using discovery based on Predictive\\nPredictive Intelligence evaluates connections\\nIntelligence to identify TCP connections and\\nbetween application \\u0000ngerprints, CIs, and Service Mapping automatically adds CI connections\\nprocesses, deploy it in large on-premise\\nprocesses, and ranks their relevancy. Service and CIs they lead to based on connection rules. You\\ndeployments. Predictive Intelligence is a machine\\nMapping uses this information to create can modify the default connection rules or create\\nAutomated Service Suggestions learning solution and needs training. To achieve\\nconnections based on connection rules. It also your own to enhance this discovery method.\\nbest results using this discovery method, you must\\ngenerates connection suggestions for servers and Discovery based on Predictive Intelligence is\\nrun discovery repeatedly.\\nload balancers for you to decide which connections effective for mapping multiple application services.\\nService Mapping may erroneously add or remove\\nto add or remove from the application services.\\ndynamic connections.\\nService Mapping uses patterns to discover and map\\nPattern-based mapping requires con\\u0000guring\\nCIs. A pattern is a sequence of commands whose Pattern-based discovery creates precise and\\ncredentials, users, and user permissions to let\\npurpose it is to detect attributes of a CI and its complete application services that reliably\\nPattern-based discovery Service Mapping access applications inside your\\noutbound connections. A typical Service Mapping represent the service-aware view of your\\norganization private network. This process may\\npattern consists of separate algorithms for organization\'s IT infrastructure.\\ntake time and effort.\\nidentifying CIs and \\u0000nding CI connections.\\nIf your organization uses tags for asset\\nmanagement, you can use these tags to map\\napplication services. Discovery and Cloud Tag-based application services may not include\\nYou can effectively use tags to map multiple\\nTag-based discovery Provisioning and Governance discover tags relevant CIs, if these CIs do not have the correct\\napplication services.\\nassigned to CIs, and populate the CMDB with this tags assigned to them.\\ndata. Service Mapping uses the tag-related data\\nfrom the CMDB to map services.\\nWhile using traf\\u0000c-based discovery creates a more\\nService Mapping can discover and map inclusive map, it may also result in mapping many\\ncon\\u0000guration items (CIs) following their traf\\u0000c- redundant CIs that do not in\\u0000uence the application\\nbased connections. This method is referred to as Using traf\\u0000c-based discovery is like casting a \\u0000ner service operation. It may clutter an application\\nTraf\\u0000c-based discovery traf\\u0000c-based mapping and it complements the net, allowing Service Mapping to \\u0000nd even those service with irrelevant CIs. Use traf\\u0000c-based\\npattern-based mapping. CIs that it failed to discover using patterns. discovery at the initial stages of discovering an\\nDepending on your con\\u0000guration, the behavior of application service and disable it once you\\ntraf\\u0000c-based discovery varies. completed discovery and \\u0000ne-tuned the applica ...
#    'documents4': '20/06/2024, 16:28 Traffic-based discovery in Service Mapping [["Table of Contents"], ["Tra\\u0000c-based discovery in Service Mapping\\nRelease version: Washington DC\\nUpdated Feb 1, 2024\\n4 minutes to read\\nSummarize [Beta]\\nService Mapping can discover and map con\\u0000guration items (CIs) following their traf\\u0000c-based connections. This method is referred to as traf\\u0000c-based mapping and it complements the pattern-based mapping.\\nWhat is traf\\u0000c-based mapping\\nUsing traf\\u0000c-based discovery is like casting a \\u0000ner net, allowing Service Mapping to \\u0000nd even those CIs that it hasn\'t discovered using patterns. If a CI has two connections, the traf\\u0000c-based connection disappears after the\\nnext top-down discovery, and any manual or pattern-based connections remain.\\nDepending on your con\\u0000guration, the behavior of traf\\u0000c-based discovery varies. If discovery based on Predictive Intelligence is enabled, Service Mapping automatically adds connections to application services based on\\nconnection rules. Service Mapping generates these suggestions based on traf\\u0000c-related data from the Con\\u0000guration Management Database (CMDB) and on Predictive Intelligence analysis of application \\u0000ngerprints, CIs,\\nand processes.\\nIf discovery based Predictive Intelligence is disabled, Service Mapping automatically adds traf\\u0000c-based connections based on the CMDB data to application services. You may need to remove connections leading to\\nirrelevant CIs to declutter application services. Typically, if the connection suggestions feature is turned off, you use traf\\u0000c-based discovery at the initial stages of discovering application services. Disable traf\\u0000c-based\\ndiscovery after you complete discovery and \\u0000ne-tuning of application services.\\nIf pattern-based discovery runs after traf\\u0000c-based discovery runs, it may create duplicate connections between CIs. In that case, the system removes the connection created using traf\\u0000c-based discovery. The system keeps\\nany connection created by traf\\u0000c-based discovery and not discovered using patterns.\\nTraf\\u0000c-related data from the CMDB\\nThe system uses commands and network \\u0000ow logs to collect traf\\u0000c-related data and saves it in the CMDB tables. Service Mapping retrieves this data from the tables to detect CI inbound and outbound connections.\\nTables containing data collected using traf\\u0000c-based methods\\nTable Source Used by Service Mapping to\\nFlow Connector [sa_\\u0000ow_connection] Net\\u0000ow and VPC logs Discover dependencies, add connections during top-down discovery.\\nDiscover all services listening on ports. In a base system, Service\\nFlow Services IP/Port and Statistics [sa_\\u0000ow_service] Net\\u0000ow and VPC logs\\nMapping does not use data from this table.\\nDiscover services communicating to other services. In a base system,\\nFlow Server Communication [sa_\\u0000ow_server_comm] Net\\u0000ow and VPC logs\\nService Mapping does not use data from this table.\\nTCP Connection [cmdb_tcp] netstat and lsof commands Discover connections during top-down discovery.\\nIn base systems, traf\\u0000c-based discovery uses only TCP-related data collected with the help of the netstat, ss, and lsof commands. Discovery based on Net\\u0000ow and VPC logs requires additional con\\u0000guration. You can\\nenrich your traf\\u0000c-based discovery by con\\u0000guring Service Mapping to perform data collection using Net\\u0000ow and VPC logs. In addition, Service Mapping has access to the TCP connection data collected by improved\\nApplication Dependency Mapping (ADM). Discovery performs ADM as part of horizontal discovery.\\nEnabling traf\\u0000c-based discovery in the system\\nBy default, traf\\u0000c-based discovery using commands is available in Service Mapping allowing it to use this method at all levels. You can enable traf\\u0000c-based discovery at diff ...
#    'documents5': '20/06/2024, 16:29 Automated Service Suggestions [["Table of Contents"], ["Automated Service Suggestions\\nRelease version: Washington DC\\nUpdated Feb 1, 2024\\n1 minute read\\nAutomated Service Suggestions uses machine-learning data to help you map a new application service or to add to an existing service in minutes.\\nService Mapping offers the visibility needed for effective service operations. Mapped services with business criticality identi\\u0000ed provide key information to make data-driven decisions, prioritize services, and respond to\\nsituations as needed.\\nUsing Machine Learning, Service Mapping identi\\u0000es potential application \\u0000ngerprints based on discovered processes. It evaluates the relationship between these \\u0000ngerprints and CIs and creates meaningful connections.\\nThese connections are used to create an application service map, a visual representation of a service. Machine Learning has reduced this process from weeks to minutes.\\nAutomated Service Suggestions takes the information provided by Machine Learning and further simpli\\u0000es the mapping process. It calculates entry points, eliminating the challenge related to knowing where to begin\\nmapping an application service. It also generates a list of application service candidates. Each candidate includes an entry point as well as a set of previously identi\\u0000ed resources to include in the service map. Then in a few\\nclicks, the user can then select a candidate to create a new application service or to add to an existing service.\\nPrevious\\nChoose the right method for discovery and mapping application services\\nNext\\nDiscovery based on Predictive Intelligence"]] https://docs.servicenow.com/bundle/washingtondc-it-operations-management/page/product/service-mapping/concept/auto-serv-suggest.html 1/2',
#    'documents6': '20/06/2024, 16:28 Pattern-based discovery in Service Mapping [["Table of Contents"], ["Pattern-based discovery in Service Mapping\\nRelease version: Washington DC\\nUpdated Feb 1, 2024\\n4 minutes to read\\nSummarize [Beta]\\nPattern-based discovery is the main method of Service Mapping collecting data about devices and applications used in application services. After Service Mapping collects data, it then creates a map of application services\\nand stores the collected data in the CMDB.\\nServiceNow applications refer to devices and applications that comprise an application service as con\\u0000guration items (CIs).\\nService Mapping uses patterns to discover and map CIs. A pattern is a sequence of commands whose purpose it is to detect attributes of a CI and its outbound connections. A typical Service Mapping pattern consists of two\\ntypes of algorithms for identifying CIs and \\u0000nding CI connections.\\nThe starting point of any discovery process is an entry point. An entry point is a point where clients access an application service. For example, to map your electronic mailing application service, de\\u0000ne an IP address or host\\nname of the email server as an entry point. The discovery and mapping process begins from Discovery performing the horizontal discovery to identify the host. Once the host discovery is complete, Service Mapping starts the\\ntop-down discovery to \\u0000nd and map applications running on this host.\\nService Mapping uses MID Servers to communicate with CIs in your organization. MID Servers are located inside your organization network and Service Mapping can communicate with them without traversing \\u0000rewalls.\\nNote: Currently, pattern operations do not support multi-languages. If values returned from pattern operations are not in English, the returned data cannot be parsed properly and the pattern discovery will fail.\\nThe discovery and mapping process consists of the following interactions:\\n1. An administrator de\\u0000nes an application service with an entry point for an application CI.\\nService Mapping creates a record for the new application service in the Mapped Application Service [cmdb_ci_service_discovered] table.\\n2. The device hosting the application is identi\\u0000ed.\\na. Service Mapping checks if the device hosting this application CI exists in the CMDB.\\nb. If the device hosting this application CI does not exist, Service Mapping triggers Discovery to detect host.\\nc. Discovery creates the \\u0000rst set of probes for port discovery, referred to as Shazzam probes, and places them as a discovery request in the External Communication Channel (ECC) queue.\\nd. The MID Server checks the ECC queue and retrieves the discovery request assigned to it.\\ne. The MID Server runs the probes against the host and discovers open ports.\\nf. The MID Server passes information on the host ports to the ECC queue.\\ng. Discovery checks the ECC queue and receives information on the host ports.\\nh. These steps are repeated for other types of probes: classi\\u0000cation, identi\\u0000cation, and exploration."]] https://docs.servicenow.com/bundle/washingtondc-it-operations-management/page/product/service-mapping/concept/pattern-based-discovery.html 1/2',
#    'documents7': '20/06/2024, 16:29 Choose the right method for discovery and mapping application services The world works with ServiceNow.™ Terms and conditions Privacy statement GDPR Cookie policy ©2024 ServiceNow. All rights reserved. https://docs.servicenow.com/bundle/washingtondc-it-operations-management/page/product/service-mapping/concept/choose-mapping-method.html 2/2',
#    'documents8': '20/06/2024, 16:28 Pattern-based discovery in Service Mapping [["i. Discovery adds the host to the CMDB.\\nj. During the host discovery using probes, Service Mapping checks the ECC queue if this process is complete. When the host discovery is complete, Service Mapping checks whether this host exists in the CMDB.\\nNote: For the detailed description of the horizontal discovery \\u0000ow, refer to Horizontal discovery process \\u0000ow with probes and sensors.\\n3. Once the host is found in the CMDB, Service Mapping discovers the application running on this host.\\na. Service Mapping creates an application discovery request for the IP address of the entry point. It then writes the request in the ECC queue and assigns a MID Server to the request.\\nb. The MID Server checks the ECC queue and retrieves the discovery request assigned to it.\\nc. The MID Server starts running identi\\u0000cation sections of the patterns associated with the classi\\u0000er to \\u0000nd the match for the entry point. When the identi\\u0000cation section matches the entry point, the pattern\\ndiscovers a CI.\\nd. The MID Server starts running connectivity sections of the pattern to \\u0000nd outgoing connections of the newly discovered CI.\\ne. The MID Server passes information on the discovered CI, its attributes, and connections to the ECC queue.\\nf. Service Mapping checks the ECC queue and receives information on the newly discovered CI.\\nWhenever Service Mapping checks the ECC queue and receives information on a discovered CI, it checks these tables for any data on outbound connections related to the CI: the cmdb_tcp and\\nsa_\\u0000ow_connection tables. If these two tables contain unique data that patterns did not discover, Service Mapping enriches the information about the CI connections and adds them to the map.\\ng. Service Mapping writes the information into the CMDB and adds this CI to the application service map.\\nh. Service Mapping creates the discovery requests for all applications to which the newly discovered CI connects. Mapping is complete after Service Mapping maps a CI that either does not have any outbound\\nconnections or is marked as a boundary. A boundary makes Service Mapping stop discovery from this point and not follow outgoing connections.\\n4. The system regularly runs the service recomputation to query the CMDB for the latest CI changes, add data for network and storage paths, and apply CI impact rules.\\nPrevious\\nDiscovery based on Predictive Intelligence\\nNext\\nTag-based discovery in Service Mapping"], ["The world works with ServiceNow.\\u2122\\nTerms and conditions\\nPrivacy statement\\nGDPR\\nCookie policy\\n\\u00a92024 ServiceNow. All rights reserved."]] https://docs.servicenow.com/bundle/washingtondc-it-operations-management/page/product/service-mapping/concept/pattern-based-discovery.html 2/2',
#    'documents9': '20/06/2024, 16:29 Automated Service Suggestions The world works with ServiceNow.™ Terms and conditions Privacy statement GDPR Cookie policy ©2024 ServiceNow. All rights reserved. https://docs.servicenow.com/bundle/washingtondc-it-operations-management/page/product/service-mapping/concept/auto-serv-suggest.html 2/2',
#    'ids0': '2',
#    'ids1': '3',
#    'ids2': '11',
#    'ids3': '6',
#    'ids4': '10',
#    'ids5': '0',
#    'ids6': '4',
#    'ids7': '7',
#    'ids8': '5',
#    'ids9': '1',
#    'metadatas0': "{'Document Name': 'Tag-based discovery in Service Mapping.pdf', 'Page No': 'Page 1'}",
#    'metadatas1': "{'Document Name': 'Tag-based discovery in Service Mapping.pdf', 'Page No': 'Page 2'}",
#    'metadatas2': "{'Document Name': 'Traffic-based discovery in Service Mapping.pdf', 'Page No': 'Page 2'}",
#    'metadatas3': "{'Document Name': 'Choose the right method for discovery and mapping application services.pdf', 'Page No': 'Page 1'}",
#    'metadatas4': "{'Document Name': 'Traffic-based discovery in Service Mapping.pdf', 'Page No': 'Page 1'}",
#    'metadatas5': "{'Document Name': 'Automated Service Suggestions.pdf', 'Page No': 'Page 1'}",
#    'metadatas6': "{'Document Name': 'Pattern-based discovery in Service Mapping.pdf', 'Page No': 'Page 1'}",
#    'metadatas7': "{'Document Name': 'Choose the right method for discovery and mapping application services.pdf', 'Page No': 'Page 2'}",
#    'metadatas8': "{'Document Name': 'Pattern-based discovery in Service Mapping.pdf', 'Page No': 'Page 2'}",
#    'metadatas9': "{'Document Name': 'Automated Service Suggestions.pdf', 'Page No': 'Page 2'}"}],
#  'documents': ['What is a tag based service?'],
#  'uris': None,
#  'data': None,
#  'included': ['embeddings', 'metadatas', 'documents']}

# %%
# Searh the Cache collection first
# Query the collection against the user query and return the top 20 results

cache_results = cache_collection.query(
    query_texts=query,
    n_results=1
)

# %%
# Implementing Cache in Semantic Search

# Set a threshold for cache search
threshold = 0.2

ids = []
documents = []
distances = []
metadatas = []
results_df = pd.DataFrame()


# If the distance is greater than the threshold, then return the results from the main collection.

if cache_results['distances'][0] == [] or cache_results['distances'][0][0] > threshold:
      # Query the collection against the user query and return the top 10 results
      results = document_collection.query(
      query_texts=query,
      n_results=10
      )

      # Store the query in cache_collection as document w.r.t to ChromaDB so that it can be embedded and searched against later
      # Store retrieved text, ids, distances and metadatas in cache_collection as metadatas, so that they can be fetched easily if a query indeed matches to a query in cache
      Keys = []
      Values = []

      for key, val in results.items():
        if val is None or key=='included':
          continue
        for i in range(10):
          Keys.append(str(key)+str(i))
          Values.append(str(val[0][i]))


      cache_collection.add(
          documents= [query],
          ids = [query],  # Or if you want to assign integers as IDs 0,1,2,.., then you can use "len(cache_results['documents'])" as will return the no. of queries currently in the cache and assign the next digit to the new query."
          metadatas = dict(zip(Keys, Values))
      )

      print("Not found in cache. Found in main collection.")

      result_dict = {'Metadatas': results['metadatas'][0], 'Documents': results['documents'][0], 'Distances': results['distances'][0], "IDs":results["ids"][0]}
      results_df = pd.DataFrame.from_dict(result_dict)
      results_df


# If the distance is, however, less than the threshold, you can return the results from cache

elif cache_results['distances'][0][0] <= threshold:
      cache_result_dict = cache_results['metadatas'][0][0]

      # Loop through each inner list and then through the dictionary
      for key, value in cache_result_dict.items():
          if 'ids' in key:
              ids.append(value)
          elif 'documents' in key:
              documents.append(value)
          elif 'distances' in key:
              distances.append(value)
          elif 'metadatas' in key:
              metadatas.append(value)

      print("Found in cache!")

      # Create a DataFrame
      results_df = pd.DataFrame({
        'IDs': ids,
        'Documents': documents,
        'Distances': distances,
        'Metadatas': metadatas
      })
# Out:
# Found in cache!

# %%
results_df
# Out:
#   IDs                                          Documents            Distances  \
# 0   2  20/06/2024, 16:27 Tag-based discovery in Servi...  0.23945076861848255
# 1   3  20/06/2024, 16:27 Tag-based discovery in Servi...   0.2805265307409776
# 2  11  20/06/2024, 16:28 Traffic-based discovery in S...  0.29892741297691583
# 3   6  20/06/2024, 16:29 Choose the right method for ...    0.312189141739491
# 4  10  20/06/2024, 16:28 Traffic-based discovery in S...  0.34174593165675354
# 5   0  20/06/2024, 16:29 Automated Service Suggestion...  0.34281026463113273
# 6   4  20/06/2024, 16:28 Pattern-based discovery in S...    0.350781140248529
# 7   5  20/06/2024, 16:28 Pattern-based discovery in S...   0.3582856419551724
# 8   7  20/06/2024, 16:29 Choose the right method for ...  0.37510334789489175
# 9   8  20/06/2024, 16:29 Discovery based on Predictiv...  0.37536001957429194
#
#                                            Metadatas
# 0  {'Document Name': 'Tag-based discovery in Serv...
# 1  {'Document Name': 'Tag-based discovery in Serv...
# 2  {'Document Name': 'Traffic-based discovery in ...
# 3  {'Document Name': 'Choose the right method for...
# 4  {'Document Name': 'Traffic-based discovery in ...
# 5  {'Document Name': 'Automated Service Suggestio...
# 6  {'Document Name': 'Pattern-based discovery in ...
# 7  {'Document Name': 'Pattern-based discovery in ...
# 8  {'Document Name': 'Choose the right method for...
# 9  {'Document Name': 'Discovery based on Predicti...

# %%
query = input()
# Out:
#  Can you explain me about the taag based service mapping?

# %%
# !ls "data"
# Out:
# Automated Service Suggestions.pdf
# Choose the right method for discovery and mapping application services.pdf
# Discovery based on Predictive Intelligence.pdf
# Pattern-based discovery in Service Mapping.pdf
# Tag-based discovery in Service Mapping.pdf
# Traffic-based discovery in Service Mapping.pdf
